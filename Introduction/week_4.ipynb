# %%
import pandas as pd

fulldata_df = pd.read_csv('./online_store_customer_data.csv')
fulldata_df.head(10)
# Out:
#   Transaction_date  Transaction_ID  Gender   Age Marital_status  State_names  \
# 0         1/1/2019          151200  Female  19.0         Single       Kansas
# 1         1/1/2019          151201    Male  49.0         Single     Illinois
# 2         1/1/2019          151202    Male  63.0        Married   New Mexico
# 3         1/1/2019          151203     NaN  18.0         Single     Virginia
# 4         1/1/2019          151204    Male  27.0         Single  Connecticut
# 5         1/3/2019          151205    Male  71.0         Single       Hawaii
# 6         1/3/2019          151206  Female  34.0        Married   New Mexico
# 7         1/3/2019          151207    Male  37.0        Married  Connecticut
# 8         1/4/2019          151208    Male  75.0        Married      Florida
# 9         1/4/2019          151209  Female  41.0        Married      Vermont
#
#     Segment Employees_status Payment_method  Referal  Amount_spent
# ...

# %% [markdown]
# 1. line code

# %%
dict_line = {
    'year' : [2016, 2017, 2018, 2019, 2020, 2021],
    'price' : [200, 250, 260, 220, 280, 300]
}
df_line = pd.DataFrame(dict_line)

#use plot() on dataframe 
df_line.plot('year', 'price');

# %%
pay_df = pd.DataFrame(fulldata_df[['Payment_method']].value_counts())
print(pay_df)
# Out:
#                 count
# Payment_method
# PayPal           1168
# Card              749
# Other             595

# %%
pay_df = pay_df.reset_index()
pay_df
# Out:
#    index Payment_method  Count
# 0      0         PayPal   1168
# 1      1           Card    749
# 2      2          Other    595

# %%
pay_df.columns = ['Payment_method', 'Count']
pay_df
# Out:
#   Payment_method  Count
# 0         PayPal   1168
# 1           Card    749
# 2          Other    595

# %%
pay_df.plot('Payment_method', 'Count', kind='line')
# Out:
# <Axes: xlabel='Payment_method'>

# %%
fulldata_df['Employees_status'].value_counts().plot(kind='bar');

# %%
fulldata_df['Employees_status'].value_counts().plot(kind='bar',
title="Employee_Status", figsize= [5,5]);

# %%
fulldata_df['Employees_status'].value_counts().plot(kind='barh');

# %%
fulldata_df['State_names'].value_counts().plot(kind='bar',
title="State_names ", figsize= [15,15]);

# %%
fulldata_df['Gender'].value_counts().plot(kind='pie',autopct='%1.5f%%')
# Out:
# <Axes: ylabel='count'>

# %%
fulldata_df.plot( y='Age', kind='hist', bins= 5, figsize=[15,9],edgecolor='black',width = 10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
fulldata_df.plot( y='Age',kind='hist',bins= 20,figsize=[15,9],edgecolor='black',width=2)
# Out:
# <Axes: ylabel='Frequency'>

# %%
fulldata_df.plot(y=['Amount_spent'], kind='box')
# Out:
# <Axes: >

# %%
# New data to append
new_data = [
    {'Transaction_ID': 160000, 'Gender': 'Male', 'Age': 40, 'Marital_status': 'Married', 
     'State_names': 'Hawaii', 'Segment': 'Basic', 'Employees_status': 'workers', 
     'Payment_method': 'PayPal', 'Referal': 1.0, 'Amount_spent': 4000},
    {'Transaction_ID': 160001, 'Gender': 'Male', 'Age': 40, 'Marital_status': 'Married', 
     'State_names': 'Hawaii', 'Segment': 'Basic', 'Employees_status': 'workers', 
     'Payment_method': 'PayPal', 'Referal': 1.0, 'Amount_spent': 5000},
    {'Transaction_ID': 160002, 'Gender': 'Male', 'Age': 40, 'Marital_status': 'Married', 
     'State_names': 'Hawaii', 'Segment': 'Basic', 'Employees_status': 'workers', 
     'Payment_method': 'PayPal', 'Referal': 1.0, 'Amount_spent': 6000},
    {'Transaction_ID': 160003, 'Gender': 'Male', 'Age': 40, 'Marital_status': 'Married', 
     'State_names': 'Hawaii', 'Segment': 'Basic', 'Employees_status': 'workers', 
     'Payment_method': 'PayPal', 'Referal': 1.0, 'Amount_spent': 7000},
    {'Transaction_ID': 160004, 'Gender': 'Male', 'Age': 40, 'Marital_status': 'Married', 
     'State_names': 'Hawaii', 'Segment': 'Basic', 'Employees_status': 'workers', 
     'Payment_method': 'PayPal', 'Referal': 1.0, 'Amount_spent': 8000},
    {'Transaction_ID': 160005, 'Gender': 'Male', 'Age': 40, 'Marital_status': 'Married', 
     'State_names': 'Hawaii', 'Segment': 'Basic', 'Employees_status': 'workers', 
     'Payment_method': 'PayPal', 'Referal': 1.0, 'Amount_spent': 9000}
]

# Convert new data to DataFrame and concatenate
fulldata_df = pd.concat([fulldata_df, pd.DataFrame(new_data)], ignore_index=True)

print(fulldata_df)
# Out:
#      Transaction_date  Transaction_ID  Gender   Age Marital_status  \
# 0            1/1/2019          151200  Female  19.0         Single
# 1            1/1/2019          151201    Male  49.0         Single
# 2            1/1/2019          151202    Male  63.0        Married
# 3            1/1/2019          151203     NaN  18.0         Single
# 4            1/1/2019          151204    Male  27.0         Single
# ...               ...             ...     ...   ...            ...
# 2513              NaN          160001    Male  40.0        Married
# 2514              NaN          160002    Male  40.0        Married
# 2515              NaN          160003    Male  40.0        Married
# 2516              NaN          160004    Male  40.0        Married
# 2517              NaN          160005    Male  40.0        Married
#
#       State_names   Segment Employees_status Payment_method  Referal  \
# 0          Kansas     Basic     Unemployment          Other      1.0
# ...

# %%
fulldata_df.plot(y=['Amount_spent'], kind='box')
# Out:
# <Axes: >

# %%
fulldata_df.boxplot(by = "Employees_status", column = ['Amount_spent'], figsize = [10, 6],grid = False, showfliers=False)
# Out:
# <Axes: title={'center': 'Amount_spent'}, xlabel='Employees_status'>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Sample data
data = {
    'Employees_status': ['Full-time', 'Part-time', 'Full-time', 'Part-time', 'Full-time'],
    'Amount_spent': [200, 150, 300, 120, 250]
}
df = pd.DataFrame(data)

# # Suppress warnings
#np.warnings.filterwarnings('ignore', category=np.VisibleDeprecationWarning)

# Create the boxplot
fig, ax = plt.subplots(figsize=(6, 6))
df.boxplot(by='Employees_status', column=['Amount_spent'], ax=ax, grid=False)
plt.title('Amount Spent by Employee Status')
plt.suptitle('')  # Suppress the default title
plt.xlabel('Employee Status')
plt.ylabel('Amount Spent')
plt.show()
