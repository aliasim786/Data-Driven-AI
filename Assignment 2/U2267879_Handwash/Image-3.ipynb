# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from os import walk
import os
import glob
import tensorflow as tf

for i in range(1,9):
    folder_path = f'./Stage {i}'
    output_folder = f'Resized_Images/Resized_Stage{i}'
    os.makedirs(output_folder, exist_ok=True)
    j = 1
# Loop through each image in the folder
    for filename in os.listdir(folder_path):
        if filename.endswith(('.jpg', '.jpeg', '.png')): 
        # Read the image
            image_path = os.path.join(folder_path, filename)
            image = cv2.imread(image_path)

            # Resize the image to 150x150
            resized_image = cv2.resize(image, (150, 150))

            # Save the resized image in the output folder
            output_path = os.path.join(output_folder, f'Stage_{i}_u2267879_({j}).jpg')
            cv2.imwrite(output_path, resized_image)

            print(f"Resized and saved {filename}")
            j += 1
# Out:
# Resized and saved IMG_0872 2.jpg
# Resized and saved IMG_0869 2.jpg
# Resized and saved IMG_0870 2.jpg
# Resized and saved IMG_0874 2.jpg
# Resized and saved IMG_0876 2.jpg
# Resized and saved IMG_0868 2.jpg
# Resized and saved IMG_0871 2.jpg
# Resized and saved IMG_0873 2.jpg
# Resized and saved IMG_0875 2.jpg
# Resized and saved IMG_0867 2.jpg
# Resized and saved IMG_0895.jpg
# Resized and saved IMG_0894.jpg
# Resized and saved IMG_0878.jpg
# Resized and saved IMG_0893.jpg
# Resized and saved IMG_0892.jpg
# Resized and saved IMG_0879.jpg
# Resized and saved IMG_0890.jpg
# Resized and saved IMG_0891.jpg
# Resized and saved IMG_0877.jpg
# Resized and saved IMG_0889.jpg
# Resized and saved IMG_0882.jpg
# Resized and saved IMG_0897.jpg
# Resized and saved IMG_0886.jpg
# Resized and saved IMG_0903.jpg
# Resized and saved IMG_0902.jpg
# Resized and saved IMG_0900.jpg
# Resized and saved IMG_0901.jpg
# Resized and saved IMG_0906.jpg
# Resized and saved IMG_0899.jpg
# Resized and saved IMG_0898.jpg
# Resized and saved IMG_0909.jpg
# Resized and saved IMG_0908.jpg
# Resized and saved IMG_0918.jpg
# Resized and saved IMG_0917.jpg
# Resized and saved IMG_0916.jpg
# Resized and saved IMG_0914.jpg
# Resized and saved IMG_0915.jpg
# Resized and saved IMG_0911.jpg
# Resized and saved IMG_0910.jpg
# Resized and saved IMG_0907.jpg
# Resized and saved IMG_0913.jpg
# Resized and saved IMG_0922.jpg
# Resized and saved IMG_0923.jpg
# Resized and saved IMG_0921.jpg
# Resized and saved IMG_0920.jpg
# Resized and saved IMG_0924.jpg
# Resized and saved IMG_0919.jpg
# Resized and saved IMG_0925.jpg
# Resized and saved IMG_0927.jpg
# Resized and saved IMG_0926.jpg
# Resized and saved IMG_0905.jpg
# Resized and saved IMG_0936.jpg
# Resized and saved IMG_0937.jpg
# Resized and saved IMG_0935.jpg
# Resized and saved IMG_0934.jpg
# Resized and saved IMG_0930.jpg
# Resized and saved IMG_0931.jpg
# Resized and saved IMG_0933.jpg
# Resized and saved IMG_0932.jpg
# Resized and saved IMG_0928.jpg
# Resized and saved IMG_0929.jpg
# Resized and saved IMG_0941.jpg
# Resized and saved IMG_0940.jpg
# Resized and saved IMG_0942.jpg
# Resized and saved IMG_0943.jpg
# Resized and saved IMG_0947.jpg
# Resized and saved IMG_0946.jpg
# Resized and saved IMG_0944.jpg
# Resized and saved IMG_0945.jpg
# Resized and saved IMG_0939.jpg
# Resized and saved IMG_0912.jpg
# Resized and saved IMG_0955.jpg
# Resized and saved IMG_0954.jpg
# Resized and saved IMG_0956.jpg
# Resized and saved IMG_0957.jpg
# Resized and saved IMG_0953.jpg
# Resized and saved IMG_0952.jpg
# Resized and saved IMG_0950.jpg
# Resized and saved IMG_0951.jpg
# Resized and saved IMG_0948.jpg
# Resized and saved IMG_0949.jpg
